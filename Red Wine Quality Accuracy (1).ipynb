# %% [markdown]
# # Avishkar Tech Solutions

# %% [markdown]
# ### Task:  To build a machine learning model on Red wine dataset with best accracy.

# %% [markdown]
# ### Name : Snehal Santosh Hidaduggi

# %% [markdown]
# ##### In this task we have to build a machine learning model on Red wine dataset with the best accuracy,

# %%
#Importing required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
# %matplotlib inline

# %%
#Getting Data
red = pd.read_csv('winequality-red.csv',delimiter=";")
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print("dimension of red wine data: {}".format(red.shape))
# Out:
# dimension of red wine data: (1599, 12)

# %%
red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
print(red.groupby('quality').size())
# Out:
# quality
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# dtype: int64

# %%
red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Visualization

# %%
red.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(red.corr(),annot=True,linewidth=0.5,center=0,cmap='coolwarm')
plt.show()

# %%
sns.countplot(red['quality'],label="Count")

# %% [markdown]
# ###### The above plot shows the distribution of the quality of the wine in the dataset, and represents that most of the wine is of average quality i.e. quality ranging from 5-7 .

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="fixed acidity", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="volatile acidity", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="citric acid", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="residual sugar", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="chlorides", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="free sulfur dioxide", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="total sulfur dioxide", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="density", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="pH", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="sulphates", data = red)
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "quality", y="alcohol", data = red)
plt.show()

# %% [markdown]
# ##### Three different patterns can be observed. First, there are positive relationships between quality and critic.acid, alcohol, and sulphates. Even though wines with a higher level of alcohol may make them less popular, they should be highly rated in quality. Second, there are negative relationships between quality and volatile.acidity, density, and pH. It is reasonable that less sweet wines and a lower level of acidity are favored in quality testings. Last, these independent variables show no significant relationship with quality: residual.sugar, chlorides, and total.sulfur.dioxide.

# %% [markdown]
# ### Building a model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(red.loc[:, red.columns != 'quality'], red['quality'], stratify=red['quality'], random_state=66)

# %% [markdown]
# #### Model 1: Random Forest

# %%
# creating a RF classifier
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100)  
  
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
  
# performing predictions on the test dataset
y_pred = clf.predict(X_test)
  
# metrics are used to find accuracy or error
from sklearn import metrics  
print()
  
# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.645

# %% [markdown]
# #### Model 2: Logistic Regression

# %%
#Fit logistic regression to the training set
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
#Predicting the test set results and creating confusion matrix
y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[  0   0   2   0   0   0]
#  [  0   0   6   6   1   0]
#  [  0   0 126  44   0   0]
#  [  0   2  66  91   1   0]
#  [  0   0   5  45   0   0]
#  [  0   0   0   5   0   0]]

# %%
#Accuracy
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(classifier.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.54

# %%
#Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        13
#            5       0.61      0.74      0.67       170
#            6       0.48      0.57      0.52       160
#            7       0.00      0.00      0.00        50
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.54       400
#    macro avg       0.18      0.22      0.20       400
# weighted avg       0.45      0.54      0.49       400
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Model 3: Linear regression

# %%
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()

lreg.fit(X_train,y_train)


pred = lreg.predict(X_test)

# %%
from pandas import Series, DataFrame
coeff = DataFrame(X_train.columns)

coeff['Coefficient Estimate'] = Series(lreg.coef_)


coeff
# Out:
#                        0  Coefficient Estimate
# 0          fixed acidity              0.032674
# 1       volatile acidity             -1.121349
# 2            citric acid             -0.180140
# 3         residual sugar              0.012491
# 4              chlorides             -2.076492
# 5    free sulfur dioxide              0.003187
# 6   total sulfur dioxide             -0.002793
# 7                density            -16.206787
# 8                     pH             -0.346335
# 9              sulphates              0.878279
# 10               alcohol              0.294825

# %%
mse = np.mean((pred - y_test)**2)

mse
# Out:
# 0.47445151409936925

# %%
lreg.score(X_test,y_test)
# Out:
# 0.2689217395132799

# %% [markdown]
# # It is reasonable that Random Forest in Model 1 gives us best “predictions”. However,  Model 2 and Model 3 may be the winners even though their performance measurements are behind. In the context of our business question focusing on the prediction of red wine quality, Model 1 will be the best choice.
